# %% [markdown]
# # Importing Pandas and as well as required Files from the Google Drive

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Reading CSV file for the Pandas Commands

# %%
ds = pd.read_csv('/content/drive/MyDrive/ETH_1H.csv')

# %% [markdown]
# #Displaying the CSV File

# %%
ds
# Out:
#        Unix Timestamp                 Date  Symbol    Open    High     Low  \
# 0       1586995200000  2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1       1586991600000  2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2       1586988000000  2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3       1586984400000  2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4       1586980800000  2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ...               ...                  ...     ...     ...     ...     ...
# 34492      1462813200  2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 34493      1462809600  2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 34494      1462806000  2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 34495      1462802400  2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 34496      1462798800  2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#         Close       Volume
# 0      150.39   650.188125
# ...

# %% [markdown]
# #Knowing about the shape and info of the Dataset

# %%
# Find out the shape - Row size and Column Size
ds.shape
# Out:
# (34497, 8)

# %%
# Give the information related to the Dataframe
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34497 entries, 0 to 34496
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unix Timestamp  34497 non-null  int64
#  1   Date            34497 non-null  object
#  2   Symbol          34497 non-null  object
#  3   Open            34497 non-null  float64
#  4   High            34497 non-null  float64
#  5   Low             34497 non-null  float64
#  6   Close           34497 non-null  float64
#  7   Volume          34497 non-null  float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 2.1+ MB

# %% [markdown]
# #Loading Column and Row display-Limit

# %% [markdown]
# "pd.set_option('display.max_rows/columns',m) "*- this is syntax for the limiting the diplay of rows or columns in output window with m number of values

# %%
# Change the number of elements (Visible in the Code Editor Output) - Jupter Notebook - VS code - Anaconda
pd.set_option('display.max_columns',15)
pd.set_option('display.max_rows',50)

# %%
ds
# Out:
#        Unix Timestamp                 Date  Symbol    Open    High     Low  \
# 0       1586995200000  2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1       1586991600000  2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2       1586988000000  2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3       1586984400000  2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4       1586980800000  2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ...               ...                  ...     ...     ...     ...     ...
# 34492      1462813200  2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 34493      1462809600  2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 34494      1462806000  2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 34495      1462802400  2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 34496      1462798800  2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#         Close       Volume
# 0      150.39   650.188125
# ...

# %% [markdown]
# #Load certain data rows from top or bottom - Head() , Tail()

# %% [markdown]
# Head() - read and display values from the beginning

# %%
#head extracts only 5 as default value
ds.head()
#head(n)- where it returns n number of values
ds.head(10)
# Out:
#    Unix Timestamp                 Date  Symbol    Open    High     Low  \
# 0   1586995200000  2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1   1586991600000  2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2   1586988000000  2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3   1586984400000  2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4   1586980800000  2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# 5   1586977200000  2020-04-15 19:00:00  ETHUSD  157.78  157.84  157.10
# 6   1586973600000  2020-04-15 18:00:00  ETHUSD  157.48  158.20  157.48
# 7   1586970000000  2020-04-15 17:00:00  ETHUSD  157.12  157.78  156.90
# 8   1586966400000  2020-04-15 16:00:00  ETHUSD  155.81  157.52  155.74
# 9   1586962800000  2020-04-15 15:00:00  ETHUSD  157.12  157.15  155.81
#
#     Close       Volume
# 0  150.39   650.188125
# 1  152.94  4277.567299
# 2  155.81   106.337279
# 3  157.18    55.244131
# 4  158.04   144.262622
# 5  157.10   329.356201
# ...

# %% [markdown]
# Tail()-read and display values from the end

# %%
ds.tail(10)
# Out:
#        Unix Timestamp                 Date  Symbol   Open   High   Low  Close  \
# 34487      1462831200  2016-05-09 22:00:00  ETHUSD   9.94   9.94  9.36   9.36
# 34488      1462827600  2016-05-09 21:00:00  ETHUSD   9.97   9.97  9.94   9.94
# 34489      1462824000  2016-05-09 20:00:00  ETHUSD   9.99   9.99  9.97   9.97
# 34490      1462820400  2016-05-09 19:00:00  ETHUSD   9.36   9.99  9.36   9.99
# 34491      1462816800  2016-05-09 18:00:00  ETHUSD   9.49   9.49  9.36   9.36
# 34492      1462813200  2016-05-09 17:00:00  ETHUSD   9.83   9.83  9.48   9.49
# 34493      1462809600  2016-05-09 16:00:00  ETHUSD   9.99   9.99  9.79   9.83
# 34494      1462806000  2016-05-09 15:00:00  ETHUSD  10.00  10.00  9.99   9.99
# 34495      1462802400  2016-05-09 14:00:00  ETHUSD   9.55  10.00  9.55  10.00
# 34496      1462798800  2016-05-09 13:00:00  ETHUSD   0.00  12.00  0.00   9.55
#
#            Volume
# 34487   25.000000
# 34488  109.177062
# 34489   10.000000
# 34490   49.500000
# ...

# %% [markdown]
# #Converting Dictionary into DataFrames

# %% [markdown]
# create an example dictionary

# %%
exmpl_dict={'Name':['Srikar','Venkat','Chami'],
            "Age":[10,22,19],
            'Height':[180,158,178]}

# %% [markdown]
# Convert Dictionary using pd.DataFrame(Dictionary_Name)

# %%
df=pd.DataFrame(exmpl_dict)

# %%
df
# Out:
#      Name  Age  Height
# 0  Srikar   10     180
# 1  Venkat   22     158
# 2   Chami   19     178

# %% [markdown]
# #Read Columns from the Dataset

# %%
ds
# Out:
#        Unix Timestamp                 Date  Symbol    Open    High     Low  \
# 0       1586995200000  2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1       1586991600000  2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2       1586988000000  2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3       1586984400000  2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4       1586980800000  2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ...               ...                  ...     ...     ...     ...     ...
# 34492      1462813200  2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 34493      1462809600  2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 34494      1462806000  2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 34495      1462802400  2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 34496      1462798800  2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#         Close       Volume
# 0      150.39   650.188125
# ...

# %% [markdown]
# Reading specific valued column from the dataframe

# %%
ds["Open"]
# Out:
# 0        152.94
# 1        155.81
# 2        157.18
# 3        158.04
# 4        157.10
#           ...
# 34492      9.83
# 34493      9.99
# 34494     10.00
# 34495      9.55
# 34496      0.00
# Name: Open, Length: 34497, dtype: float64

# %% [markdown]
# Adding Head and Tail to those column readings

# %%
ds['Open'].head(8)
# Out:
# 0    152.94
# 1    155.81
# 2    157.18
# 3    158.04
# 4    157.10
# 5    157.78
# 6    157.48
# 7    157.12
# Name: Open, dtype: float64

# %%
ds['Open'].tail(8)
# Out:
# 34489     9.99
# 34490     9.36
# 34491     9.49
# 34492     9.83
# 34493     9.99
# 34494    10.00
# 34495     9.55
# 34496     0.00
# Name: Open, dtype: float64

# %% [markdown]
# Read 'n' columns at a time as a new dataframe

# %%
#n= name of columns
ds[['Open','Close']]
# Out:
#          Open   Close
# 0      152.94  150.39
# 1      155.81  152.94
# 2      157.18  155.81
# 3      158.04  157.18
# 4      157.10  158.04
# ...       ...     ...
# 34492    9.83    9.49
# 34493    9.99    9.83
# 34494   10.00    9.99
# 34495    9.55   10.00
# 34496    0.00    9.55
#
# [34497 rows x 2 columns]

# %% [markdown]
# using Head() and Tail() for the new temporary Dataframe

# %%
ds[["Open","Close"]].head(8)
# Out:
#      Open   Close
# 0  152.94  150.39
# 1  155.81  152.94
# 2  157.18  155.81
# 3  158.04  157.18
# 4  157.10  158.04
# 5  157.78  157.10
# 6  157.48  157.78
# 7  157.12  157.48

# %% [markdown]
# #Integer Location

# %% [markdown]
# ##iloc is used to read and display specific rows

# %% [markdown]
# To print out the number of rows we want with integer as the row identifier

# %%
ds.iloc[0]
# Out:
# Unix Timestamp          1586995200000
# Date              2020-04-16 00:00:00
# Symbol                         ETHUSD
# Open                           152.94
# High                           152.94
# Low                            150.39
# Close                          150.39
# Volume                     650.188125
# Name: 0, dtype: object

# %% [markdown]
# We can also make a new DataFrame with iloc[ [ ] ]

# %%
ds.iloc[[0,1,2]]  #Prints 3 rows with index -0,1,2
# Out:
#    Unix Timestamp                 Date  Symbol    Open    High     Low  \
# 0   1586995200000  2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1   1586991600000  2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2   1586988000000  2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
#
#     Close       Volume
# 0  150.39   650.188125
# 1  152.94  4277.567299
# 2  155.81   106.337279

# %% [markdown]
# ##Specific Column for specific Rows

# %% [markdown]
# ###Using iloc we can print out specific column for a specified row index

# %% [markdown]
# iloc[[r1,r2,....,rn],[c1,c2,...cn]] - to read the specific column value to the corresponding row value. We must only use integers for all the specifying values in the "[ ]"

# %%
ds.iloc[[1,3,4],[2,4,6,3,1]]
# Out:
#    Symbol    High   Close    Open                 Date
# 1  ETHUSD  155.81  152.94  155.81  2020-04-15 23:00:00
# 3  ETHUSD  158.31  157.18  158.04  2020-04-15 21:00:00
# 4  ETHUSD  158.10  158.04  157.10  2020-04-15 20:00:00

# %%
ds.iloc[[1],[1,2,3]]
# Out:
#                   Date  Symbol    Open
# 1  2020-04-15 23:00:00  ETHUSD  155.81

# %% [markdown]
# ###Loc- Label(name) based Read and display

# %% [markdown]
# Using loc[ ] we can read and print the values using the column labels.
#
# Syntax - ds.loc[[r1,r2,....rn],[c_name1,c_name2,....c_name_n]]

# %%
ds.loc[[0,1],['Open','Close']]
# Out:
#      Open   Close
# 0  152.94  150.39
# 1  155.81  152.94

# %% [markdown]
# Individual Value for a specific plot

# %%
ds.loc[1,"Open"]
# Out:
# 155.81

# %%
ds.loc[[1,2,3],"Open"]
# Out:
# 1    155.81
# 2    157.18
# 3    158.04
# Name: Open, dtype: float64

# %% [markdown]
# ###Slicing using loc[ ]

# %%
ds.loc[1:5,"Open":"Volume"]
# Out:
#      Open    High     Low   Close       Volume
# 1  155.81  155.81  151.39  152.94  4277.567299
# 2  157.18  157.30  155.32  155.81   106.337279
# 3  158.04  158.31  157.16  157.18    55.244131
# 4  157.10  158.10  156.87  158.04   144.262622
# 5  157.78  157.84  157.10  157.10   329.356201

# %%
ds.loc[1:5:2,"Open":"Volume":2]
# Out:
#      Open     Low       Volume
# 1  155.81  151.39  4277.567299
# 3  158.04  157.16    55.244131
# 5  157.78  157.10   329.356201

# %% [markdown]
# Slicing the rows

# %%
ds.loc[1:5]
# Out:
#    Unix Timestamp                 Date  Symbol    Open    High     Low  \
# 1   1586991600000  2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2   1586988000000  2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3   1586984400000  2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4   1586980800000  2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# 5   1586977200000  2020-04-15 19:00:00  ETHUSD  157.78  157.84  157.10
#
#     Close       Volume
# 1  152.94  4277.567299
# 2  155.81   106.337279
# 3  157.18    55.244131
# 4  158.04   144.262622
# 5  157.10   329.356201

# %%
ds.loc[1:5:2]
# Out:
#    Unix Timestamp                 Date  Symbol    Open    High     Low  \
# 1   1586991600000  2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 3   1586984400000  2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 5   1586977200000  2020-04-15 19:00:00  ETHUSD  157.78  157.84  157.10
#
#     Close       Volume
# 1  152.94  4277.567299
# 3  157.18    55.244131
# 5  157.10   329.356201

# %% [markdown]
# Slicing the columns

# %%
ds.loc[0:1]
# Out:
#    Unix Timestamp                 Date  Symbol    Open    High     Low  \
# 0   1586995200000  2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1   1586991600000  2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
#
#     Close       Volume
# 0  150.39   650.188125
# 1  152.94  4277.567299

# %%
ds.loc[0:1,"Unix Timestamp":"Volume":2]
# Out:
#    Unix Timestamp  Symbol    High   Close
# 0   1586995200000  ETHUSD  152.94  150.39
# 1   1586991600000  ETHUSD  155.81  152.94

# %% [markdown]
# #Set Index

# %% [markdown]
# ##Set an index using : ds.set_index('column_name',inplace=True)

# %% [markdown]
# Inplace = True } makes the dataset permanent

# %%
ds.set_index("Close",inplace=True)

# %% [markdown]
# Here Close is the index for this present Dataset

# %%
ds
# Out:
#         Unix Timestamp                 Date  Symbol    Open    High     Low  \
# Close
# 150.39   1586995200000  2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 152.94   1586991600000  2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 155.81   1586988000000  2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 157.18   1586984400000  2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 158.04   1586980800000  2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ...                ...                  ...     ...     ...     ...     ...
# 9.49        1462813200  2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 9.83        1462809600  2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 9.99        1462806000  2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 10.00       1462802400  2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 9.55        1462798800  2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#              Volume
# Close
# ...

# %% [markdown]
# ###Reset index using : reset_index(inplace=True)

# %%
ds.reset_index(inplace=True)

# %% [markdown]
# Now the "Close" label is not index anymore

# %%
ds
# Out:
#         Close  Unix Timestamp                 Date  Symbol    Open    High  \
# 0      150.39   1586995200000  2020-04-16 00:00:00  ETHUSD  152.94  152.94
# 1      152.94   1586991600000  2020-04-15 23:00:00  ETHUSD  155.81  155.81
# 2      155.81   1586988000000  2020-04-15 22:00:00  ETHUSD  157.18  157.30
# 3      157.18   1586984400000  2020-04-15 21:00:00  ETHUSD  158.04  158.31
# 4      158.04   1586980800000  2020-04-15 20:00:00  ETHUSD  157.10  158.10
# ...       ...             ...                  ...     ...     ...     ...
# 34492    9.49      1462813200  2016-05-09 17:00:00  ETHUSD    9.83    9.83
# 34493    9.83      1462809600  2016-05-09 16:00:00  ETHUSD    9.99    9.99
# 34494    9.99      1462806000  2016-05-09 15:00:00  ETHUSD   10.00   10.00
# 34495   10.00      1462802400  2016-05-09 14:00:00  ETHUSD    9.55   10.00
# 34496    9.55      1462798800  2016-05-09 13:00:00  ETHUSD    0.00   12.00
#
#           Low       Volume
# 0      150.39   650.188125
# ...

# %% [markdown]
# ##Queries Usage after "set_index"

# %% [markdown]
# setting close as index

# %%
ds.set_index("Close",inplace=True)

# %% [markdown]
# read row with index of close at "155.81"

# %%
ds.loc[155.81]
# Out:
#         Unix Timestamp                 Date  Symbol    Open    High     Low  \
# Close
# 155.81   1586988000000  2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 155.81   1586962800000  2020-04-15 15:00:00  ETHUSD  157.12  157.15  155.81
# 155.81   1546704000000  2019-01-05 16:00:00  ETHUSD  156.41  157.68  154.00
#
#              Volume
# Close
# 155.81   106.337279
# 155.81   303.839541
# 155.81  1457.966396

# %% [markdown]
# ##Sort using Filter

# %% [markdown]
# Sorting the dataset using :::sort_index(ascending=True/False,inplace=True)

# %%
ds
# Out:
#         Unix Timestamp                 Date  Symbol    Open    High     Low  \
# Close
# 150.39   1586995200000  2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 152.94   1586991600000  2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 155.81   1586988000000  2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 157.18   1586984400000  2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 158.04   1586980800000  2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ...                ...                  ...     ...     ...     ...     ...
# 9.49        1462813200  2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 9.83        1462809600  2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 9.99        1462806000  2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 10.00       1462802400  2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 9.55        1462798800  2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#              Volume
# Close
# ...

# %% [markdown]
# deafult sort for ascending value is True

# %%
ds.sort_index()
# Out:
#          Unix Timestamp                 Date  Symbol     Open     High  \
# Close
# 6.10         1481018400  2016-12-06 10:00:00  ETHUSD     6.33     6.90
# 6.15         1481022000  2016-12-06 11:00:00  ETHUSD     6.10     6.15
# 6.32         1481025600  2016-12-06 12:00:00  ETHUSD     6.15     6.32
# 6.33         1481014800  2016-12-06 09:00:00  ETHUSD     6.55     6.55
# 6.50         1480989600  2016-12-06 02:00:00  ETHUSD     6.82     6.82
# ...                 ...                  ...     ...      ...      ...
# 1386.74      1515880800  2018-01-13 22:00:00  ETHUSD  1394.93  1400.00
# 1388.99      1515862800  2018-01-13 17:00:00  ETHUSD  1366.48  1389.00
# 1394.93      1515877200  2018-01-13 21:00:00  ETHUSD  1417.54  1420.00
# 1416.00      1515866400  2018-01-13 18:00:00  ETHUSD  1388.99  1419.89
# 1417.54      1515873600  2018-01-13 20:00:00  ETHUSD  1382.00  1420.01
#
#              Low       Volume
# Close
# 6.10        5.99   791.938578
# 6.15        6.07    26.135373
# ...

# %% [markdown]
# Reverse the sort

# %%
ds.sort_index(ascending=False)

# %%
import math
u_values=[]
for _ in range(1,100000):
    u_values.append(_)
y=[]
for u in u_values:
    y.append(-(math.log((u/(100000-u)),2.718)))
y_sorted=sorted(y)
y_sorted.remove(0.0)
print(y_sorted)
n=2
i=[1,2]
g1=[0,-0.1628]
d1=[0.5906,0.4317]
num=[]
ys1=y_sorted[0:50000]
ys2=y_sorted[50000:100000]
print(len(ys1),len(ys2))
for _ in range(len(ys1)):
    for _ in range(len(ys2)):
        num.append(((((2*0.5906)-1)*ys1[_])/(n))+((((2*0.4317)-1)*ys2[_])/(n)))
num
# Out:
# [-11.51410929694945, -10.82088023928999, -10.415363085181296, -10.127641180143515, -9.904464488466694, -9.722114024247752, -9.567937358075206, -9.434382117122823, -9.316576866064786, -9.21119542305877, -9.115865357976029, -9.028834956152494, -8.94877394616134, -8.8746482869925, -8.80563825880087, -8.74108304275254, -8.680442131777182, -8.623267788106782, -8.56918495744729, -8.517876341212887, -8.469071114658696, -8.422536271942095, -8.378069896657045, -8.335495865630325, -8.29465963458462, -8.255424850850739, -8.217670605695801, -8.18128918659325, -8.146184224098722, -8.112269153012747, -8.07946592596014, -8.0477039312753, -8.016919077452362, -7.987053014310573, -7.9580524670855315, -7.929868664350532, -7.902456844336508, -7.875775827101117, -7.849787642280375, -7.824457203976493, -7.7997520257960895, -7.775641970231771, -7.752099027536917, -7.729097120024312, -7.706611928359565, -7.684620736948068, -7.663102295951072, -7.6420366978297976, -7.621405266619802, -7.601190458392175, -7.5
# ...

# %%
pip install tensorflow

# %%
import tensorflow as tf

# %%
tf.compat.v1.disable_eager_execution()
a = tf.constant(10)

# %%
sess = tf.compat.v1.Session()

# %%
c = tf.add(a,a)
result = sess.run(c)
print(result)
# Out:
# 20

# %%
node1 = tf.constant(3,dtype =tf.int32)
node2 = tf.constant(5,dtype = tf.int32)
node3 = sess.run(node1*node2)
print(node3)
# Out:
# 15

# %%
node1 = tf.constant(100,200)
node2 = tf.constant(1000,2000)
node3 = node1*node2
print(node3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-de43e9328309> in <cell line: 1>()
# ----> 1 node1 = tf.constant(100,200)
#       2 node2 = tf.constant(1000,2000)
#       3 node3 = node1*node2
#       4 print(node3)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     265     ValueError: if called on a symbolic tensor.
#     266   """
# --> 267   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     268                         allow_broadcast=True)
#     269
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     279     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     280
# ...
